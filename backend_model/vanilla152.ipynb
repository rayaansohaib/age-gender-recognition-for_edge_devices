# %%
# ============================== 0. Runtime setup ==============================

import tensorflow as tf, numpy as np, pickle, os, random, time, math, json
from pathlib import Path
import matplotlib.pyplot as plt
from google.colab import drive
import torch, numpy as np, tensorflow as tf
import tensorflow as tf, torch, pickle, numpy as np, os, random
gpus = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)  # don’t pre-grab all VRAM
tf.keras.mixed_precision.set_global_policy('mixed_float16')  # ½-size tensors
from torch.utils.data import Dataset , DataLoader

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, mean_absolute_error
import seaborn as sns
import os
import tensorflow as tf
import pickle
import torch
import torch.nn as nn
import torch.optim as optim


class UTKFaceDataset(Dataset):
    def __init__(self, images, ages, genders, ethnicities):
        self.images = images
        self.ages = ages
        self.genders = genders
        self.ethnicities = ethnicities

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        # Get labels
        age = torch.tensor(self.ages[idx], dtype=torch.float32)
        gender = torch.tensor(self.genders[idx], dtype=torch.float32)
        ethnicity = torch.tensor(self.ethnicities[idx], dtype=torch.long)
        #
        return image, age, gender, ethnicity
# ------------------------------------------------------------------------------
# 1.  Mount Google Drive
# ------------------------------------------------------------------------------
drive.mount('/content/drive')

# ------------------------------------------------------------------------------
# 5.  Model definition (ResNet-152 w/ ReLU age head)
# ------------------------------------------------------------------------------
from tensorflow.keras.layers import (Input, Conv2D, LayerNormalization, ReLU,
                                     Dropout, Add, MaxPooling2D,
                                     GlobalAveragePooling2D, Dense)
from tensorflow.keras.models import Model
import torch, torch.nn as nn
from torchvision.models import resnet152, ResNet152_Weights

import torch
import torch.nn as nn
from torchvision.models import resnet152, ResNet152_Weights

class AgeGenderNet(nn.Module):
    def __init__(self, dropout: float = 0.2, unfreeze_layers: list[str] = None):
        super().__init__()
        # Load pretrained ResNet-152 backbone
        self.backbone = resnet152(weights=ResNet152_Weights.IMAGENET1K_V2)
        self.backbone.fc = nn.Identity()  # remove original classification head

        # Determine which backbone layers to unfreeze
        # Default: unfreeze layer3 and layer4 for deeper fine-tuning
        if unfreeze_layers is None:
            unfreeze_layers = ["layer3", "layer4"]

        # Freeze all backbone layers, then unfreeze selected ones
        for name, param in self.backbone.named_parameters():
            param.requires_grad = any(name.startswith(layer) for layer in unfreeze_layers)

        # Shared BatchNorm + Dropout on feature vector
        self.bn_shared = nn.BatchNorm1d(2048)
        self.drop_shared = nn.Dropout(dropout)

        # Age regression head with LeakyReLU activation
        self.age_head = nn.Sequential(
            nn.Linear(2048, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.1),
            nn.Dropout(dropout),
            nn.Linear(256,128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.1),
            nn.Dropout(dropout),
            nn.Linear(128,1)

        )

        # Gender classification head with ReLU activation
        self.gender_head = nn.Sequential(
            nn.Linear(2048, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(),  # introduces nonlinearity before final layer
            nn.Dropout(dropout),
            nn.Linear(256,128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(),
            nn.Dropout(dropout),
            nn.Linear(128,1)

        )

    def forward(self, x: torch.Tensor) -> tuple[torch.Tensor, torch.Tensor]:
        # Extract backbone features
        feat = self.backbone(x)
        feat = self.bn_shared(feat)
        feat = self.drop_shared(feat)

        # Compute age and gender outputs
        age_logits = self.age_head(feat)         # raw regression value
        gender_logits = self.gender_head(feat)   # raw classification score
        gender_prob = torch.sigmoid(gender_logits)

        return age_logits, gender_prob




device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DROPOUT_RATE=0.2
model = AgeGenderNet(dropout=DROPOUT_RATE).to(device)

import torch.nn as nn
import torch.optim as optim
criterion_age = nn.MSELoss()
criterion_gender = nn.BCELoss()
criterion_ethnicity = nn.CrossEntropyLoss()


optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=2.5e-4,weight_decay=1e-6)




chunk_dir = "/content/drive/MyDrive/pkl_files"
chunk_files = sorted([
    os.path.join(chunk_dir, f) for f in os.listdir(chunk_dir) if f.endswith('.pkl')
])

losses = []
f1_scores = []
num_epochs=10
# --- 1. Training step ---
def train_epoch(model, dataloader, optimizer, device):
    model.train()
    running_loss = 0.0
    for images, ages, genders, _ in dataloader:
        if isinstance(images, list):
            images = torch.stack(images)
        images = images.to(device)
        ages   = ages.to(device).unsqueeze(1)
        genders= genders.to(device).unsqueeze(1).float()

        optimizer.zero_grad()
        out_age, out_gender = model(images)

        loss_age    = criterion_age(out_age, ages)
        loss_gender = criterion_gender(out_gender, genders)
        loss = 0.5 * loss_age + 1.5 * loss_gender

        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    return running_loss / len(dataloader)

# --- 2. Validation loss only ---
def evaluate_loss(model, dataloader, device):
    model.eval()
    running_loss = 0.0
    with torch.no_grad():
        for images, ages, genders, _ in dataloader:
            if isinstance(images, list):
                images = torch.stack(images)
            images = images.to(device)
            ages   = ages.to(device).unsqueeze(1)
            genders= genders.to(device).unsqueeze(1).float()

            out_age, out_gender = model(images)
            loss_age    = criterion_age(out_age, ages)
            loss_gender = criterion_gender(out_gender, genders)
            loss = 0.5 * loss_age + 1.5 * loss_gender
            running_loss += loss.item()

    return running_loss / len(dataloader)

# --- 3. Continuous training across chunks ---
train_losses, val_losses = [], []

for i, chunk_path in enumerate(chunk_files[:-9]):
    # Load your chunk as before
    with open(chunk_path, 'rb') as f:
        data = pickle.load(f)
    images = data['images']
    ages   = data['ages']
    genders= data['genders']
    ethnics= data['ethnicities']

    # Build datasets and loaders
    train_df, val_df = train_test_split(list(zip(images, ages, genders, ethnics)),
                                         test_size=0.25, random_state=42)
    train_dataset = UTKFaceDataset(*zip(*train_df))
    val_dataset   = UTKFaceDataset(*zip(*val_df))
    train_loader  = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader    = torch.utils.data.DataLoader(val_dataset,   batch_size=32, shuffle=False)

    # Epoch loop for this chunk
    for epoch in range(num_epochs):
        tr_loss = train_epoch(model, train_loader, optimizer, device)
        vl_loss = evaluate_loss(model, val_loader, device)

        train_losses.append(tr_loss)
        val_losses.append(vl_loss)

        print(f"Chunk {i} | Epoch {epoch+1}/{num_epochs} | "
              f"Train Loss: {tr_loss:.4f} | Val Loss: {vl_loss:.4f}")

# --- 4. Plot continuous train vs val loss ---
plt.figure(figsize=(10,6))
plt.plot(train_losses, label='Train Loss', marker='o')
plt.plot(val_losses,   label='Val Loss',   marker='s')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.title('Train vs Val Loss Across All Chunks and Epochs')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Chunk 0 | Epoch 1/10 | Train Loss: 718.7242 | Val Loss: 664.4247
# Chunk 0 | Epoch 2/10 | Train Loss: 675.3740 | Val Loss: 596.6793
# Chunk 0 | Epoch 3/10 | Train Loss: 644.9661 | Val Loss: 609.9230
# Chunk 0 | Epoch 4/10 | Train Loss: 631.7270 | Val Loss: 575.8055
# Chunk 0 | Epoch 5/10 | Train Loss: 616.7766 | Val Loss: 590.2003
# Chunk 0 | Epoch 6/10 | Train Loss: 605.4560 | Val Loss: 582.7481
# Chunk 0 | Epoch 7/10 | Train Loss: 593.7132 | Val Loss: 591.8921
# Chunk 0 | Epoch 8/10 | Train Loss: 583.3680 | Val Loss: 566.8528
# Chunk 0 | Epoch 9/10 | Train Loss: 566.9652 | Val Loss: 572.7283
# Chunk 0 | Epoch 10/10 | Train Loss: 556.2590 | Val Loss: 525.3754
# Chunk 1 | Epoch 1/10 | Train Loss: 636.4583 | Val Loss: 620.0786
# Chunk 1 | Epoch 2/10 | Train Loss: 617.6812 | Val Loss: 435.6910
# Chunk 1 | Epoch 3/10 | Train Loss: 597.7332 | Val Loss: 549.0710
# Chunk 1 | Epoch 4/10 | Train Loss: 582.9536 | Val Loss: 566.7801
# Chunk 1 | Epoch 5/10 | Train Loss: 567.7624 | Val Loss: 570.7566
# Chunk 1 | Epoch 6/10 | Train Loss: 539.3681 | Val Loss: 434.2419
# Chunk 1 | Epoch 7/10 | Train Loss: 518.7776 | Val Loss: 515.5578
# Chunk 1 | Epoch 8/10 | Train Loss: 507.2909 | Val Loss: 462.5467
# Chunk 1 | Epoch 9/10 | Train Loss: 502.0768 | Val Loss: 462.4367
# Chunk 1 | Epoch 10/10 | Train Loss: 482.6166 | Val Loss: 471.1358
# Chunk 2 | Epoch 1/10 | Train Loss: 419.8369 | Val Loss: 454.6714
# Chunk 2 | Epoch 2/10 | Train Loss: 403.2552 | Val Loss: 493.2709
# Chunk 2 | Epoch 3/10 | Train Loss: 380.5071 | Val Loss: 312.1135
# Chunk 2 | Epoch 4/10 | Train Loss: 366.2626 | Val Loss: 370.5143
# Chunk 2 | Epoch 5/10 | Train Loss: 353.6291 | Val Loss: 392.2790
# Chunk 2 | Epoch 6/10 | Train Loss: 330.4183 | Val Loss: 408.3239
# Chunk 2 | Epoch 7/10 | Train Loss: 318.8619 | Val Loss: 264.2669
# Chunk 2 | Epoch 8/10 | Train Loss: 307.2503 | Val Loss: 366.4316
# Chunk 2 | Epoch 9/10 | Train Loss: 290.6915 | Val Loss: 312.2191
# Chunk 2 | Epoch 10/10 | Train Loss: 271.3950 | Val Loss: 296.4257
# Chunk 3 | Epoch 1/10 | Train Loss: 306.8961 | Val Loss: 266.3137
# Chunk 3 | Epoch 2/10 | Train Loss: 289.3692 | Val Loss: 368.0057
# Chunk 3 | Epoch 3/10 | Train Loss: 269.0122 | Val Loss: 199.5713
# Chunk 3 | Epoch 4/10 | Train Loss: 252.3174 | Val Loss: 280.8754
# Chunk 3 | Epoch 5/10 | Train Loss: 227.4964 | Val Loss: 317.0937
# Chunk 3 | Epoch 6/10 | Train Loss: 212.3791 | Val Loss: 236.0536
# Chunk 3 | Epoch 7/10 | Train Loss: 194.8781 | Val Loss: 257.4389
# Chunk 3 | Epoch 8/10 | Train Loss: 175.8818 | Val Loss: 201.0009
# Chunk 3 | Epoch 9/10 | Train Loss: 173.1468 | Val Loss: 240.9242
# Chunk 3 | Epoch 10/10 | Train Loss: 159.8540 | Val Loss: 148.4328
# Chunk 4 | Epoch 1/10 | Train Loss: 158.6076 | Val Loss: 217.2870
# Chunk 4 | Epoch 2/10 | Train Loss: 137.3201 | Val Loss: 165.7751
# Chunk 4 | Epoch 3/10 | Train Loss: 113.4799 | Val Loss: 173.5256
# Chunk 4 | Epoch 4/10 | Train Loss: 109.1101 | Val Loss: 181.9321
# Chunk 4 | Epoch 5/10 | Train Loss: 94.2030 | Val Loss: 171.0888
# Chunk 4 | Epoch 6/10 | Train Loss: 79.6502 | Val Loss: 147.1203
# Chunk 4 | Epoch 7/10 | Train Loss: 73.0442 | Val Loss: 136.5746
# Chunk 4 | Epoch 8/10 | Train Loss: 66.8765 | Val Loss: 128.7143
# Chunk 4 | Epoch 9/10 | Train Loss: 63.9361 | Val Loss: 151.0335
# Chunk 4 | Epoch 10/10 | Train Loss: 65.9383 | Val Loss: 113.7026
# Chunk 5 | Epoch 1/10 | Train Loss: 133.3494 | Val Loss: 114.7904
# Chunk 5 | Epoch 2/10 | Train Loss: 103.7671 | Val Loss: 102.5533
# Chunk 5 | Epoch 3/10 | Train Loss: 84.2769 | Val Loss: 156.1184
# Chunk 5 | Epoch 4/10 | Train Loss: 70.1088 | Val Loss: 85.5875
# Chunk 5 | Epoch 5/10 | Train Loss: 62.8459 | Val Loss: 100.2753
# Chunk 5 | Epoch 6/10 | Train Loss: 56.8796 | Val Loss: 92.6950
# Chunk 5 | Epoch 7/10 | Train Loss: 47.5530 | Val Loss: 90.0752
# Chunk 5 | Epoch 8/10 | Train Loss: 52.3092 | Val Loss: 95.1885
# Chunk 5 | Epoch 9/10 | Train Loss: 45.2762 | Val Loss: 89.1578
# Chunk 5 | Epoch 10/10 | Train Loss: 40.9626 | Val Loss: 84.0669
# Chunk 6 | Epoch 1/10 | Train Loss: 78.1372 | Val Loss: 90.1513
# Chunk 6 | Epoch 2/10 | Train Loss: 54.7436 | Val Loss: 91.1985
# Chunk 6 | Epoch 3/10 | Train Loss: 35.9576 | Val Loss: 93.2597
# Chunk 6 | Epoch 4/10 | Train Loss: 34.3615 | Val Loss: 82.1362
# Chunk 6 | Epoch 5/10 | Train Loss: 28.2249 | Val Loss: 68.5845
# Chunk 6 | Epoch 6/10 | Train Loss: 28.5934 | Val Loss: 82.2963
# Chunk 6 | Epoch 7/10 | Train Loss: 26.0995 | Val Loss: 77.5385
# Chunk 6 | Epoch 8/10 | Train Loss: 27.7848 | Val Loss: 79.1377
# Chunk 6 | Epoch 9/10 | Train Loss: 24.3017 | Val Loss: 79.1112
# Chunk 6 | Epoch 10/10 | Train Loss: 21.9792 | Val Loss: 82.0694
# Chunk 7 | Epoch 1/10 | Train Loss: 78.5681 | Val Loss: 79.0966
# Chunk 7 | Epoch 2/10 | Train Loss: 45.8665 | Val Loss: 67.6920
# Chunk 7 | Epoch 3/10 | Train Loss: 35.3987 | Val Loss: 77.6009
# Chunk 7 | Epoch 4/10 | Train Loss: 32.1545 | Val Loss: 74.3122
# Chunk 7 | Epoch 5/10 | Train Loss: 29.0886 | Val Loss: 67.1201
# Chunk 7 | Epoch 6/10 | Train Loss: 25.3084 | Val Loss: 62.8904
# Chunk 7 | Epoch 7/10 | Train Loss: 22.7963 | Val Loss: 76.8073
# Chunk 7 | Epoch 8/10 | Train Loss: 21.8798 | Val Loss: 72.1491
# Chunk 7 | Epoch 9/10 | Train Loss: 21.8501 | Val Loss: 70.8948
# Chunk 7 | Epoch 10/10 | Train Loss: 23.6425 | Val Loss: 82.9267
# Chunk 8 | Epoch 1/10 | Train Loss: 75.3063 | Val Loss: 62.8930
# Chunk 8 | Epoch 2/10 | Train Loss: 40.8490 | Val Loss: 65.8776
# Chunk 8 | Epoch 3/10 | Train Loss: 27.9417 | Val Loss: 65.2471
# Chunk 8 | Epoch 4/10 | Train Loss: 27.5332 | Val Loss: 59.4117
# Chunk 8 | Epoch 5/10 | Train Loss: 23.8347 | Val Loss: 71.7597
# Chunk 8 | Epoch 6/10 | Train Loss: 22.0259 | Val Loss: 58.1753
# Chunk 8 | Epoch 7/10 | Train Loss: 16.1927 | Val Loss: 55.6084
# Chunk 8 | Epoch 8/10 | Train Loss: 19.8224 | Val Loss: 61.5123
# Chunk 8 | Epoch 9/10 | Train Loss: 17.4991 | Val Loss: 58.3248
# Chunk 8 | Epoch 10/10 | Train Loss: 16.9656 | Val Loss: 55.5635
# Chunk 9 | Epoch 1/10 | Train Loss: 74.2265 | Val Loss: 69.9255
# Chunk 9 | Epoch 2/10 | Train Loss: 41.4178 | Val Loss: 69.8618
# Chunk 9 | Epoch 3/10 | Train Loss: 37.0171 | Val Loss: 61.9783
# Chunk 9 | Epoch 4/10 | Train Loss: 23.2562 | Val Loss: 59.2895
# Chunk 9 | Epoch 5/10 | Train Loss: 29.8507 | Val Loss: 57.4653
# Chunk 9 | Epoch 6/10 | Train Loss: 17.7723 | Val Loss: 59.0833
# Chunk 9 | Epoch 7/10 | Train Loss: 18.9414 | Val Loss: 73.3185
# Chunk 9 | Epoch 8/10 | Train Loss: 18.4244 | Val Loss: 64.9344
# Chunk 9 | Epoch 9/10 | Train Loss: 15.6996 | Val Loss: 59.0658
# Chunk 9 | Epoch 10/10 | Train Loss: 18.3488 | Val Loss: 62.4372
# Chunk 10 | Epoch 1/10 | Train Loss: 67.5885 | Val Loss: 52.6950
# Chunk 10 | Epoch 2/10 | Train Loss: 30.7201 | Val Loss: 59.1731
# Chunk 10 | Epoch 3/10 | Train Loss: 26.1873 | Val Loss: 49.3891
# Chunk 10 | Epoch 4/10 | Train Loss: 25.1651 | Val Loss: 49.3724
# Chunk 10 | Epoch 5/10 | Train Loss: 22.1909 | Val Loss: 54.1403
# Chunk 10 | Epoch 6/10 | Train Loss: 20.1726 | Val Loss: 48.4314
# Chunk 10 | Epoch 7/10 | Train Loss: 17.7426 | Val Loss: 50.7058
# Chunk 10 | Epoch 8/10 | Train Loss: 16.7808 | Val Loss: 52.0075
# Chunk 10 | Epoch 9/10 | Train Loss: 16.9513 | Val Loss: 47.4317
# Chunk 10 | Epoch 10/10 | Train Loss: 16.4468 | Val Loss: 47.2528
# Chunk 11 | Epoch 1/10 | Train Loss: 54.7061 | Val Loss: 55.4476
# Chunk 11 | Epoch 2/10 | Train Loss: 28.0415 | Val Loss: 56.9626
# Chunk 11 | Epoch 3/10 | Train Loss: 23.4739 | Val Loss: 50.8196
# Chunk 11 | Epoch 4/10 | Train Loss: 21.0033 | Val Loss: 52.2435
# Chunk 11 | Epoch 5/10 | Train Loss: 22.0382 | Val Loss: 52.1722
# Chunk 11 | Epoch 6/10 | Train Loss: 20.5194 | Val Loss: 54.9615
# Chunk 11 | Epoch 7/10 | Train Loss: 20.9441 | Val Loss: 51.5638
# Chunk 11 | Epoch 8/10 | Train Loss: 15.4367 | Val Loss: 53.0150
# Chunk 11 | Epoch 9/10 | Train Loss: 18.8315 | Val Loss: 47.8947
# Chunk 11 | Epoch 10/10 | Train Loss: 16.0952 | Val Loss: 46.9573
# Chunk 12 | Epoch 1/10 | Train Loss: 54.7036 | Val Loss: 53.1787
# Chunk 12 | Epoch 2/10 | Train Loss: 33.2843 | Val Loss: 57.5185
# Chunk 12 | Epoch 3/10 | Train Loss: 20.5119 | Val Loss: 57.6060
# Chunk 12 | Epoch 4/10 | Train Loss: 16.2130 | Val Loss: 57.1585
# Chunk 12 | Epoch 5/10 | Train Loss: 18.8251 | Val Loss: 57.7169
# Chunk 12 | Epoch 6/10 | Train Loss: 14.1765 | Val Loss: 49.5523
# Chunk 12 | Epoch 7/10 | Train Loss: 15.4528 | Val Loss: 56.2870
# Chunk 12 | Epoch 8/10 | Train Loss: 11.8041 | Val Loss: 55.1660
# Chunk 12 | Epoch 9/10 | Train Loss: 12.8030 | Val Loss: 52.3155
# Chunk 12 | Epoch 10/10 | Train Loss: 13.0778 | Val Loss: 55.9048
# Chunk 13 | Epoch 1/10 | Train Loss: 65.5333 | Val Loss: 53.7572
# Chunk 13 | Epoch 2/10 | Train Loss: 29.6368 | Val Loss: 44.7965
# Chunk 13 | Epoch 3/10 | Train Loss: 23.6736 | Val Loss: 43.5421
# Chunk 13 | Epoch 4/10 | Train Loss: 26.1180 | Val Loss: 47.1106
# Chunk 13 | Epoch 5/10 | Train Loss: 22.8673 | Val Loss: 44.1205
# Chunk 13 | Epoch 6/10 | Train Loss: 18.4651 | Val Loss: 42.9351
# Chunk 13 | Epoch 7/10 | Train Loss: 16.9119 | Val Loss: 44.8594
# Chunk 13 | Epoch 8/10 | Train Loss: 17.2824 | Val Loss: 42.8144
# Chunk 13 | Epoch 9/10 | Train Loss: 18.9575 | Val Loss: 42.6863
# Chunk 13 | Epoch 10/10 | Train Loss: 18.3804 | Val Loss: 43.2025
# Chunk 14 | Epoch 1/10 | Train Loss: 49.8882 | Val Loss: 49.8569
# Chunk 14 | Epoch 2/10 | Train Loss: 33.1871 | Val Loss: 52.5919
# Chunk 14 | Epoch 3/10 | Train Loss: 26.1857 | Val Loss: 50.2433
# Chunk 14 | Epoch 4/10 | Train Loss: 18.4269 | Val Loss: 45.4306
# Chunk 14 | Epoch 5/10 | Train Loss: 14.8924 | Val Loss: 55.1742
# Chunk 14 | Epoch 6/10 | Train Loss: 16.6221 | Val Loss: 53.7155
# Chunk 14 | Epoch 7/10 | Train Loss: 11.7398 | Val Loss: 53.1320
# Chunk 14 | Epoch 8/10 | Train Loss: 13.5116 | Val Loss: 52.3669
# Chunk 14 | Epoch 9/10 | Train Loss: 13.9133 | Val Loss: 51.0282
# Chunk 14 | Epoch 10/10 | Train Loss: 13.4400 | Val Loss: 53.9192

# %%
#load chunk 17, and run it as a validation
chunk_path = '/content/drive/MyDrive/pkl_files/chunk_17.pkl'
with open(chunk_path, 'rb') as f:
    data_dict = pickle.load(f)

print(len(data_dict['ages']))
df = []
for i in range(len(data_dict['ages'])):
  thing = [data_dict['images'][i], data_dict['ages'][i], data_dict['genders'][i], data_dict['ethnicities'][i]]

  df.append(thing)

val_ages = [row[1] for row in df]
val_genders = [row[2] for row in df]
val_ethnicities = [row[3] for row in df]

val_images = [row[0] for row in df]

val_dataset = UTKFaceDataset(val_images,val_ages,val_genders,val_ethnicities)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False)


##perform prediction
model.eval().to(device)
test_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False)



#confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

true_genders = []
pred_genders = []
true_ethnicities = []
pred_ethnicities = []

with torch.no_grad():
    for images, ages, genders, ethnicities in test_loader:

      images = images.to(device)
      ages = ages.to(device).unsqueeze(1)
      genders = genders.to(device).unsqueeze(1).float()
      out_age, out_gender = model(images)

      true_genders.extend(genders.cpu().numpy())
      pred_genders.extend((out_gender > 0.52).float().cpu().numpy())
      # true_ethnicities.extend(ethnicities.cpu().numpy())
      # pred_ethnicities.extend(out_ethnicity.argmax(dim=1).cpu().numpy())

# Confusion matrix for gender
cm_gender = confusion_matrix(true_genders, pred_genders)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_gender, annot=True, fmt='d', cmap='Blues', xticklabels=['Female', 'Male'], yticklabels=['Female', 'Male'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Gender')
plt.show()

#classfication report
from sklearn.metrics import classification_report
print(classification_report(true_genders, pred_genders))

#confusion matrix for age
true_ages = []
pred_ages = []

with torch.no_grad():
    for images, ages, genders, ethnicities in test_loader:
        images = images.to(device)
        ages = ages.to(device).unsqueeze(1)
        genders = genders.to(device).unsqueeze(1).float()
        out_age, out_gender = model(images)
        true_ages.extend(ages.cpu().numpy())
        pred_ages.extend(out_age.cpu().numpy())

# Scatter plot for age prediction
plt.figure(figsize=(8, 6))
plt.scatter(true_ages, pred_ages, alpha=0.5)
plt.xlabel('True Age')
plt.ylabel('Predicted Age')
plt.title('Age Prediction Scatter Plot')
plt.plot([min(true_ages), max(true_ages)], [min(true_ages), max(true_ages)], 'r--')
plt.show()

#calculate r^2
from sklearn.metrics import r2_score
r2 = r2_score(true_ages, pred_ages)
print(r2)

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(true_ages, pred_ages)
print(mae)
# Out:
# 1002
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.90      0.87       567
#          1.0       0.85      0.78      0.81       435
#
#     accuracy                           0.85      1002
#    macro avg       0.85      0.84      0.84      1002
# weighted avg       0.85      0.85      0.84      1002
# 0.7874620017965063
# 6.805598309683704

# %%
import torch, pathlib
# !pip install onnx
import onnx
onnx_path = pathlib.Path("/content/drive/MyDrive/age_gender.onnx")

model.eval().cpu()                          # ONNX export needs CPU tensors
dummy = torch.randn(1, 3, 224, 224)         # NCHW, batch-size 1

torch.onnx.export(
    model, dummy, onnx_path,
    input_names  = ["image"],
    output_names = ["age", "gender"],
    dynamic_axes = {"image":  {0: "batch"},
                    "age":    {0: "batch"},
                    "gender": {0: "batch"}},
    opset_version=17,                       # 17 ↔ TF 2.16+
)
print("✅  ONNX written to", onnx_path)
